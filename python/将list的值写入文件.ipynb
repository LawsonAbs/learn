# %%
a=[['慢性前列腺炎', 0.344224, -0.076145, -0.988508, 1.090956, -0.503372, 0.024065, 0.354971, -0.624777, -0.524144, -0.302605, -1.200655, 0.450614, 0.024969, 0.575663, 0.391732, -1.546275, -0.548433, -0.139994, -0.787002, 0.313937, -0.209102, -0.07076, 0.19339, 0.161052, 0.137617, 0.252558, -0.00046, -0.227301, -0.092986, -0.042248, 0.528441, -0.005232, 0.111273, 0.152613, -0.210307, -0.562216, 0.072227, -0.144945,0.136565, 0.382415, -0.548379, 0.384397, -1.04848, -0.189141, -0.205653, 1.916375, 0.002828, 0.26674, -0.100723, -0.474586]]

for i in range(0,len(a)):
    print(type(i)) # <class 'list'>
    s = str(a[i]).replace('[', '').replace(']', '')
    s = s.replace("'", '').replace(",", '') + '\n'
    print(s)
# Out:
# <class 'int'>
# 慢性前列腺炎 0.344224 -0.076145 -0.988508 1.090956 -0.503372 0.024065 0.354971 -0.624777 -0.524144 -0.302605 -1.200655 0.450614 0.024969 0.575663 0.391732 -1.546275 -0.548433 -0.139994 -0.787002 0.313937 -0.209102 -0.07076 0.19339 0.161052 0.137617 0.252558 -0.00046 -0.227301 -0.092986 -0.042248 0.528441 -0.005232 0.111273 0.152613 -0.210307 -0.562216 0.072227 -0.144945 0.136565 0.382415 -0.548379 0.384397 -1.04848 -0.189141 -0.205653 1.916375 0.002828 0.26674 -0.100723 -0.474586

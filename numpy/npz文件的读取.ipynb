# %%
import numpy as np
data = np.load("/home/lawson/program/EWISE/conve/saved_embeddings/embeddings_projected.npz")
print(type(data))
print(data.files) # 看得到什么文件
print(type(data['embeddings'])) # 取embeddings
emb_0 = data['embeddings'][0] 
print(emb_0.size)  # synset的大小是200 维的向量
synset = data['synsets'][0] # 取synset 
print(f"{synset}的embedding是: {emb_0}")
# Out:
# <class 'numpy.lib.npyio.NpzFile'>
# ['embeddings', 'synsets']
# <class 'numpy.ndarray'>
# 200
# 'hood.n.01的embedding是: [ 0.00291466  0.01332365  0.09018776  0.04868795 -0.02029942 -0.09025083
#  -0.05899388 -0.14877574  0.256986   -0.1562617   0.00182978  0.00707604
#   0.06335491 -0.05599761 -0.09588703  0.00381384  0.07271224  0.09532575
#   0.02774894  0.12882331 -0.15496126 -0.05503121 -0.07821026 -0.0342156
#   0.12522721  0.10174491 -0.05362111 -0.06670372 -0.07760625  0.06217517
#   0.094      -0.0518932   0.14185244 -0.01458959 -0.06914058 -0.15795794
#  -0.12755251 -0.0036076   0.04597223  0.09632877 -0.06936774 -0.08575696
#  -0.12296088  0.00806698 -0.07091439  0.15594414 -0.16013548 -0.14256655
#  -0.06847633  0.13540259 -0.05099712 -0.08133011 -0.03707985  0.02338483
#   0.00968627 -0.00585941 -0.02204088 -0.03971391  0.01548379  0.05154981
#   0.1484115  -0.05211765 -0.09440947 -0.06333855 -0.06070615  0.00056189
# ...

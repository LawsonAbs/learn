# %%
relations = [
"influenced by",
"sister city",
"separated from",
"territory claimed by",
"narrative location",
"position held",
"replaces",
"replaced by",
"genre",
"residence",
"original language of work",
"lyrics by",
"product or material produced",
"location of formation",
"end time",
"series",
"parent taxon",
"mother",
"dissolved, ... or demolished",
"capital",
]
nepg_f1 = [66.67,100, 66.67, 0,36.36,50.00,0,11.11,44.44,11.11,55.56,41.86,41.18,68.42,55.56,60.00,79.25,63.49,49.32,60.53,]
EICR_f1 = [0.00,0.00,0.00,0.00,75.00,20.00,11.76,11.11,46.15,11.76,62.50,41.18,45.00,73.91,44.44,62.75,65.31,76.71,57.58,44.07]
import matplotlib.pyplot as plt
plt.figure(figsize = (10,5))
plt.plot(relations, nepg_f1, color='green', linewidth=2.0,marker='o',label='NEPG')
plt.plot(relations, EICR_f1, color='red', linewidth=2.0,marker='+',label='EICR')

# ax = plt.figure()
plt.xticks(rotation=-90)  # 这里是调节横坐标的倾斜度，rotation是度数
plt.ylabel("F1")
plt.legend()



# 开始画纵轴图 => 画出每个类型的关系数量
relations_num = [1,2,2,2,7,8,13,13,14,15,19,19,22,24,26,27,28,32,36,37]
ax2 = plt.twinx()
ax2.bar(relations,relations_num)
ax2.set_ylim(0,100)
ax2.set_ylabel("Number")
plt.savefig("长尾性能对比.png",dpi=200,bbox_inches = "tight")
plt.show()  # 显示图片，防止闪退

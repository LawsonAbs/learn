# %%
'''画出熵值的图像
'''
from matplotlib import pyplot as plt
import math
import numpy as np
x = np.arange(0.0000001,1,0.000001) # 注意区间，因为logx中的x是
y = []
for i in x:    
    temp = -i*math.log(i) # 这个表达式就是熵值
    y.append(temp)
plt.plot(x,y)  # Plot some data on the axes.

# %%
import torch as t
import torch.nn as nn
out = t.tensor([[[-387.5796, -163.1063, -698.4470, -725.6780, -470.6840, -405.0457,
          -506.6984, -172.3996, -533.2958, -244.7965, -261.3687, -605.6010,
          -498.2119, -870.5081, -597.6240, -663.8558, -293.1742, -340.1140,
          -835.9951, -265.2243, -117.1791, -466.1007, -233.2999, -585.0398,
          -435.6255, -448.4660, -782.4313,   84.1404, -747.5856, -216.2993]],

        [[   0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000]],

        [[-512.8802, -606.4031, -674.4161, -131.9275, -381.8470, -586.4958,
          -326.9682, -352.0484, -451.6766, -466.7753, -434.0390, -162.1775,
          -536.1713,  -48.4076, -514.4053, -535.7240, -550.3710, -441.5213,
          -937.9450, -330.3545, -214.8103, -377.5759,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000]],

        [[-439.9100, -487.1731, -553.4623, -340.7871, -261.9231, -356.0400,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000,
             0.0000,    0.0000,    0.0000,    0.0000,    0.0000,    0.0000]]])
print(out.shape)
sf = nn.Softmax(2)
score = sf(out)
print(score)
# Out:
# torch.Size([4, 1, 30])
# tensor([[[0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#         [[3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02,
#           3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02,
#           3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02,
#           3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02,
#           3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02,
#           3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02, 3.3333e-02]],
#
#         [[0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...
